# %%
# define an optimizer for model compilation
def optimizer(name, **kwargs):
    from tensorflow.keras import optimizers
    if name == 'Adam':
        return optimizers.Adam(**kwargs)
    elif name == 'Adadelta':
        return optimizers.Adadelta(**kwargs)
    elif name == 'Adagrad':
        return optimizers.Adagrad(**kwargs)
    elif name == 'Adamax':
        return optimizers.Adamax(**kwargs)
    elif name == 'Ftrl':
        return optimizers.Ftrl(**kwargs)
    elif name == 'Nadam':
        return optimizers.Nadam(**kwargs)
    elif name == 'RMSprop':
        return optimizers.RMSprop(**kwargs)
    elif name == 'SGD':
        return optimizers.SGD(**kwargs)
    else:
        return None

print(type(optimizer('Adam')))
print(type(optimizer('Adadelta')))
print(type(optimizer('Adagrad')))
print(type(optimizer('Adamax', )))
print(type(optimizer('Ftrl')))
print(type(optimizer('Nadam')))
print(type(optimizer('RMSprop')))
print(type(optimizer('SGD')))
# Out:
# 2022-04-29 01:35:18.162125: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>
# <class 'tensorflow.python.keras.optimizer_v2.adadelta.Adadelta'>
# <class 'tensorflow.python.keras.optimizer_v2.adagrad.Adagrad'>
# <class 'tensorflow.python.keras.optimizer_v2.adamax.Adamax'>
# <class 'tensorflow.python.keras.optimizer_v2.ftrl.Ftrl'>
# <class 'tensorflow.python.keras.optimizer_v2.nadam.Nadam'>
# <class 'tensorflow.python.keras.optimizer_v2.rmsprop.RMSprop'>
# <class 'tensorflow.python.keras.optimizer_v2.gradient_descent.SGD'>

# %%
# define layer weight regularizers
def regularizer(reg_name, **kwargs):
    from keras import regularizers
    if reg_name == 'l1':
        return regularizers.L1(**kwargs)
    elif reg_name == 'l2':
        return regularizers.L2(**kwargs)
    elif reg_name == 'l1l2':
        return regularizers.L1L2(**kwargs)
    else:
        return None

print(regularizer('l1'))
print(regularizer('l2'))
print(regularizer('l1l2'))
# Out:
# <tensorflow.python.keras.regularizers.L1 object at 0x7f18a0088f40>
# <tensorflow.python.keras.regularizers.L2 object at 0x7f18a0070910>
# <tensorflow.python.keras.regularizers.L1L2 object at 0x7f18a0088f40>

# %%
# define layer weight initializer
def initializer(init_name, **kwargs):
    from keras import initializers
    if init_name == 'RandomNormal':
        return initializers.RandomNormal(**kwargs)
    elif init_name == 'RandomUniform':
        return initializers.RandomUniform(**kwargs)
    elif init_name == 'TruncatedNormal':
        return initializers.TruncatedNormal(**kwargs)
    elif init_name == 'Zeros':
        return initializers.Zeros(**kwargs)
    elif init_name == 'Ones':
        return initializers.Ones(**kwargs)
    elif init_name == 'GlorotNormal':
        return initializers.GlorotNormal(**kwargs)
    elif init_name == 'GlorotUniform':
        return initializers.GlorotUniform(**kwargs)
    elif init_name == 'HeNormal':
        return initializers.HeNormal(**kwargs)
    elif init_name == 'HeUniform':
        return initializers.HeUniform(**kwargs)
    elif init_name == 'Identity':
        return initializers.Identity(**kwargs)
    elif init_name == 'Orthogonal':
        return initializers.Orthogonal(**kwargs)
    elif init_name == 'Constant':
        return initializers.Constant(**kwargs)
    elif init_name == 'VarianceScaling':
        return initializers.VarianceScaling(**kwargs)
    else:
        return None

print(initializer('RandomNormal'))
print(initializer('RandomUniform'))
print(initializer('TruncatedNormal'))
print(initializer('Zeros'))
print(initializer('Ones'))
print(initializer('GlorotNormal'))
print(initializer('GlorotUniform'))
print(initializer('HeNormal'))
print(initializer('HeUniform'))
print(initializer('Identity'))
print(initializer('Orthogonal'))
print(initializer('Constant'))
print(initializer('VarianceScaling'))
# Out:
# <tensorflow.python.keras.initializers.initializers_v2.RandomNormal object at 0x7f18a00b5fa0>
# <tensorflow.python.keras.initializers.initializers_v2.RandomUniform object at 0x7f18a0070ca0>
# <tensorflow.python.keras.initializers.initializers_v2.TruncatedNormal object at 0x7f18a00b5fa0>
# <tensorflow.python.keras.initializers.initializers_v2.Zeros object at 0x7f18a0070ca0>
# <tensorflow.python.keras.initializers.initializers_v2.Ones object at 0x7f18a00b5fa0>
# <tensorflow.python.keras.initializers.initializers_v2.GlorotNormal object at 0x7f18a0070ca0>
# <tensorflow.python.keras.initializers.initializers_v2.GlorotUniform object at 0x7f18a00b5fa0>
# <tensorflow.python.keras.initializers.initializers_v2.HeNormal object at 0x7f18a0070ca0>
# <tensorflow.python.keras.initializers.initializers_v2.HeUniform object at 0x7f18a00b5fa0>
# <tensorflow.python.keras.initializers.initializers_v2.Identity object at 0x7f18a0070ca0>
# <tensorflow.python.keras.initializers.initializers_v2.Orthogonal object at 0x7f18a00b5fa0>
# <tensorflow.python.keras.initializers.initializers_v2.Constant object at 0x7f18a0070ca0>
# <tensorflow.python.keras.initializers.initializers_v2.VarianceScaling object at 0x7f18a00b5fa0>

# %%
# define layer weight constraints
def constraint(const_name, **kwargs):
    from keras import constraints
    if const_name == 'MaxNorm':
        return constraints.MaxNorm(**kwargs)
    elif const_name == 'MinMaxNorm':
        return constraints.MinMaxNorm(**kwargs)
    elif const_name == 'NonNeg':
        return constraints.NonNeg(**kwargs)
    elif const_name == 'UnitNorm':
        return constraints.UnitNorm(**kwargs)
    else:
        return None

print(constraint('MaxNorm'))
print(constraint('MinMaxNorm'))
print(constraint('NonNeg'))
print(constraint('UnitNorm'))
# Out:
# <tensorflow.python.keras.constraints.MaxNorm object at 0x7f18a0071160>
# <tensorflow.python.keras.constraints.MinMaxNorm object at 0x7f18a0071430>
# <tensorflow.python.keras.constraints.NonNeg object at 0x7f18a0071160>
# <tensorflow.python.keras.constraints.UnitNorm object at 0x7f18a0071430>

# %%
# define keras layers
def layer(layer_name, **kwargs):
    from tensorflow.keras import layers
    # reccurrent layers (RNN)
    if layer_name == 'LSTM':
        return layers.LSTM(**kwargs)
    elif layer_name == 'GRU':
        return layers.GRU(**kwargs)
    elif layer_name == 'SimpleRNN':
        return layers.SimpleRNN(**kwargs)
    elif layer_name == 'TimeDistributed':
        return layers.TimeDistributed(**kwargs)
    elif layer_name == 'Bidirectional':
        return layers.Bidirectional(**kwargs)
    elif layer_name == 'ConvLSTM2D':
        return layers.ConvLSTM2D(**kwargs)
    elif layer_name == 'RNN':
        return layers.RNN(**kwargs)
    # convolution layers (CNN)
    elif layer_name == 'Conv1D':
        return layers.Conv1D(**kwargs)#filters=16, kernel_size=(1, ))
    elif layer_name == 'Conv2D':
        return layers.Conv2D(**kwargs)
    elif layer_name == 'Conv3D':
        return layers.Conv3D(**kwargs)
    elif layer_name == 'SeparableConv1D':
        return layers.SeparableConv1D(**kwargs)
    elif layer_name == 'SeparableConv2D':
        return layers.SeparableConv2D(**kwargs)
    elif layer_name == 'DepthwiseConv2D':
        return layers.DepthwiseConv2D(**kwargs)
    elif layer_name == 'Conv2DTranspose':
        return layers.Conv2DTranspose(**kwargs)
    elif layer_name == 'Conv3DTranspose':
        return layers.Conv3DTranspose(**kwargs)
    # activation layers
    elif layer_name == 'ReLU':
        return layers.ReLU(**kwargs)
    elif layer_name == 'Softmax':
        return layers.Softmax(**kwargs)
    elif layer_name == 'LeakyReLU':
        return layers.LeakyReLU(**kwargs)
    elif layer_name == 'PReLU':
        return layers.PReLU(**kwargs)
    elif layer_name == 'ELU':
        return layers.ELU(**kwargs)
    elif layer_name == 'ThresholdedReLU':
        return layers.ThresholdedReLU(**kwargs)
    # pooling layers
    elif layer_name == 'MaxPooling1D':
        return layers.MaxPooling1D(**kwargs)
    elif layer_name == 'MaxPooling2D':
        return layers.MaxPooling2D(**kwargs)
    elif layer_name == 'MaxPooling3D':
        return layers.MaxPooling3D(**kwargs)
    elif layer_name == 'AveragePooling1D':
        return layers.AveragePooling1D(**kwargs)
    elif layer_name == 'AveragePooling2D':
        return layers.AveragePooling2D(**kwargs)
    elif layer_name == 'AveragePooling3D':
        return layers.AveragePooling3D(**kwargs)
    elif layer_name == 'GlobalMaxPooling1D':
        return layers.GlobalMaxPooling1D(**kwargs)
    elif layer_name == 'GlobalMaxPooling2D':
        return layers.GlobalMaxPooling2D(**kwargs)
    elif layer_name == 'GlobalMaxPooling3D':
        return layers.GlobalMaxPooling3D(**kwargs)
    elif layer_name == 'GlobalAveragePooling1D':
        return layers.GlobalAveragePooling1D(**kwargs)
    elif layer_name == 'GlobalAveragePooling2D':
        return layers.GlobalAveragePooling2D(**kwargs)
    elif layer_name == 'GlobalAveragePooling3D':
        return layers.GlobalAveragePooling3D(**kwargs)
    # core layers
    elif layer_name == 'Input':
        from keras import Input
        return Input(**kwargs)
    elif layer_name == 'Dense':
        return layers.Dense(**kwargs)
    elif layer_name == 'Activation':
        return layers.Activation(**kwargs)
    elif layer_name == 'Embedding':
        return layers.Embedding(**kwargs)
    elif layer_name == 'Masking':
        return layers.Masking(**kwargs)
    elif layer_name == 'Lambda':
        return layers.Lambda(**kwargs)
    # normalization layers
    elif layer_name == 'BatchNormalization':
        return layers.BatchNormalization(**kwargs)
    elif layer_name == 'LayerNormalization':
        return layers.LayerNormalization(**kwargs)
    # regularization layers
    elif layer_name == 'Dropout':
        return layers.Dropout(**kwargs)
    elif layer_name == 'SpatialDropout1D':
        return layers.SpatialDropout1D(**kwargs)
    elif layer_name == 'SpatialDropout2D':
        return layers.SpatialDropout2D(**kwargs)
    elif layer_name == 'SpatialDropout3D':
        return layers.SpatialDropout3D(**kwargs)
    elif layer_name == 'GaussianDropout':
        return layers.GaussianDropout(**kwargs)
    elif layer_name == 'GaussianNoise':
        return layers.GaussianNoise(**kwargs)
    elif layer_name == 'ActivityRegularization':
        return layers.ActivityRegularization(**kwargs)
    elif layer_name == 'AlphaDropout':
        return layers.AlphaDropout(**kwargs)
    # attention layers
    elif layer_name == 'MultiHeadAttention':
        return layers.MultiHeadAttention(**kwargs)
    elif layer_name == 'Attention':
        return layers.Attention(**kwargs)
    elif layer_name == 'AdditiveAttention':
        return layers.AdditiveAttention(**kwargs)
    # reshaping layers
    elif layer_name == 'Reshape':
        return layers.Reshape(**kwargs)
    elif layer_name == 'Flatten':
        return layers.Flatten(**kwargs)
    elif layer_name == 'RepeatVector':
        return layers.RepeatVector(**kwargs)
    elif layer_name == 'Permute':
        return layers.Permute(**kwargs)
    elif layer_name == 'Cropping1D':
        return layers.Cropping1D(**kwargs)
    elif layer_name == 'Cropping2D':
        return layers.Cropping2D(**kwargs)
    elif layer_name == 'Cropping3D':
        return layers.Cropping3D(**kwargs)
    elif layer_name == 'UpSampling1D':
        return layers.UpSampling1D(**kwargs)
    elif layer_name == 'UpSampling2D':
        return layers.UpSampling2D(**kwargs)
    elif layer_name == 'UpSampling3D':
        return layers.UpSampling3D(**kwargs)
    elif layer_name == 'ZeroPadding1D':
        return layers.ZeroPadding1D(**kwargs)
    elif layer_name == 'ZeroPadding2D':
        return layers.ZeroPadding2D(**kwargs)
    elif layer_name == 'ZeroPadding3D':
        return layers.ZeroPadding3D(**kwargs)
    # merging layers
    elif layer_name == 'Concatenate':
        return layers.Concatenate(**kwargs)
    elif layer_name == 'Average':
        return layers.Average(**kwargs)
    elif layer_name == 'Maximum':
        return layers.Maximum(**kwargs)
    elif layer_name == 'Minimum':
        return layers.Minimum(**kwargs)
    elif layer_name == 'Add':
        return layers.Add(**kwargs)
    elif layer_name == 'Subtract':
        return layers.Subtract(**kwargs)
    elif layer_name == 'Multiply':
        return layers.Multiply(**kwargs)
    elif layer_name == 'Dot':
        return layers.Dot(**kwargs)
    # locally connecteg layers
    elif layer_name == 'LocallyConnected1D':
        return layers.LocallyConnected1D(**kwargs)
    elif layer_name == 'LocallyConnected2D':
        return layers.LocallyConnected2D(**kwargs)
    else:
        return None

print('>>>>>>>>>> Recurrent Layers (RNN) <<<<<<<<<<')
print(layer('LSTM', units=16))
print(layer('GRU', units=16))
print(layer('SimpleRNN', units=16))
print(layer('TimeDistributed', layer=layer('LSTM', units=16)))
print(layer('Bidirectional', layer=layer('LSTM', units=16)))
print(layer('ConvLSTM2D', filters=16, kernel_size=(2, 2)))
# print(recc_layer('RNN', cell=None))
print('>>>>>>>>>> Convolutoin Layers (CNN) <<<<<<<<<<')
print(layer('Conv1D', filters=16, kernel_size=2))
print(layer('Conv2D', filters=16, kernel_size=(2, 2)))
print(layer('Conv3D', filters=16, kernel_size=(2, 2, 2)))
print(layer('SeparableConv1D', filters=16, kernel_size=(2,)))
print(layer('SeparableConv2D', filters=16, kernel_size=(2, 2)))
print(layer('DepthwiseConv2D', kernel_size=(2, 2)))
print(layer('Conv2DTranspose', filters=16, kernel_size=(2, 2)))
print(layer('Conv3DTranspose', filters=16, kernel_size=(2, 2, 2)))
# activation layers
print('>>>>>>>>>> Activation Layers <<<<<<<<<<')
print(layer('ReLU'))
print(layer('Softmax'))
print(layer('LeakyReLU'))
print(layer('PReLU'))
print(layer('ELU'))
print(layer('ThresholdedReLU'))
# pooling layers
print('>>>>>>>>>> Pooling Layers <<<<<<<<<<')
print(layer('MaxPooling1D'))
print(layer('MaxPooling2D'))
print(layer('MaxPooling3D'))
print(layer('AveragePooling1D'))
print(layer('AveragePooling2D'))
print(layer('AveragePooling3D'))
print(layer('GlobalMaxPooling1D'))
print(layer('GlobalMaxPooling2D'))
print(layer('GlobalMaxPooling3D'))
print(layer('GlobalAveragePooling1D'))
print(layer('GlobalAveragePooling2D'))
print(layer('GlobalAveragePooling3D'))
# core layers
print('>>>>>>>>>> Core Layers <<<<<<<<<<')
print(layer('Input', shape=(4, )))
print(layer('Dense', units=1))
print(layer('Activation', activation='relu'))
print(layer('Embedding', input_dim=5, output_dim=2))
print(layer('Masking'))
print(layer('Lambda', function=lambda x: x+1))
# normalization layers
print('>>>>>>>>>> Normalization Layers <<<<<<<<<<')
print(layer('BatchNormalization'))
print(layer('LayerNormalization'))
# regularization layers
print('>>>>>>>>>> Regularization Layers <<<<<<<<<<')
print(layer('Dropout', rate=0.3))
print(layer('SpatialDropout1D', rate=0.3))
print(layer('SpatialDropout2D', rate=0.3))
print(layer('SpatialDropout3D', rate=0.3))
print(layer('GaussianDropout', rate=0.3))
print(layer('GaussianNoise', stddev=0.3))
print(layer('ActivityRegularization'))
print(layer('AlphaDropout', rate=0.3))
# attention layers
print('>>>>>>>>>> Attention Layers <<<<<<<<<<')
print(layer('MultiHeadAttention', num_heads=3, key_dim=4))
print(layer('Attention'))
print(layer('AdditiveAttention'))
# reshaping layers
print('>>>>>>>>>> Reshaping Layers <<<<<<<<<<')
print(layer('Reshape', target_shape=(2, 3)))
print(layer('Flatten'))
print(layer('RepeatVector', n=5))
print(layer('Permute', dims=(1, 2)))
print(layer('Cropping1D'))
print(layer('Cropping2D'))
print(layer('Cropping3D'))
print(layer('UpSampling1D'))
print(layer('UpSampling2D'))
print(layer('UpSampling3D'))
print(layer('ZeroPadding1D'))
print(layer('ZeroPadding2D'))
print(layer('ZeroPadding3D'))
# merging layers
print('>>>>>>>>>> Merging Layers <<<<<<<<<<')
print(layer('Concatenate'))
print(layer('Average'))
print(layer('Maximum'))
print(layer('Minimum'))
print(layer('Add'))
print(layer('Subtract'))
print(layer('Multiply'))
print(layer('Dot', axes=1))
# locally connected layers
print('>>>>>>>>>> Locally Connected Layers <<<<<<<<<<')
print(layer('LocallyConnected1D', filters=16, kernel_size=(2, )))
print(layer('LocallyConnected2D', filters=16, kernel_size=(2, 2)))
# Out:
# >>>>>>>>>> Recurrent Layers (RNN) <<<<<<<<<<
# <tensorflow.python.keras.layers.recurrent_v2.LSTM object at 0x7f18a0070c70>
# <tensorflow.python.keras.layers.recurrent_v2.GRU object at 0x7f18299f6640>
# <tensorflow.python.keras.layers.recurrent.SimpleRNN object at 0x7f1828ab1820>
# <tensorflow.python.keras.layers.wrappers.TimeDistributed object at 0x7f1828b33ac0>
# <tensorflow.python.keras.layers.wrappers.Bidirectional object at 0x7f1828b33040>
# <tensorflow.python.keras.layers.convolutional_recurrent.ConvLSTM2D object at 0x7f1828af5160>
# >>>>>>>>>> Convolutoin Layers (CNN) <<<<<<<<<<
# <tensorflow.python.keras.layers.convolutional.Conv1D object at 0x7f1828af5160>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1828ac8760>
# <tensorflow.python.keras.layers.convolutional.Conv3D object at 0x7f1828af5160>
# <tensorflow.python.keras.layers.convolutional.SeparableConv1D object at 0x7f1828ac8880>
# <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x7f1828af5160>
# <tensorflow.python.keras.layers.convolutional.DepthwiseConv2D object at 0x7f1828ac8af0>
# <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x7f1828af5160>
# <tensorflow.python.keras.layers.convolutional.Conv3DTranspose object at 0x7f1828ac8b20>
# >>>>>>>>>> Activation Layers <<<<<<<<<<
# <tensorflow.python.keras.layers.advanced_activations.ReLU object at 0x7f1828ac8a00>
# <tensorflow.python.keras.layers.advanced_activations.Softmax object at 0x7f1828ac89d0>
# <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f1828ac8b50>
# <tensorflow.python.keras.layers.advanced_activations.PReLU object at 0x7f1828ac8430>
# <tensorflow.python.keras.layers.advanced_activations.ELU object at 0x7f1828ac82e0>
# <tensorflow.python.keras.layers.advanced_activations.ThresholdedReLU object at 0x7f1828ac89d0>
# >>>>>>>>>> Pooling Layers <<<<<<<<<<
# <tensorflow.python.keras.layers.pooling.MaxPooling1D object at 0x7f1828aa2040>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f18299f65e0>
# <tensorflow.python.keras.layers.pooling.MaxPooling3D object at 0x7f18299f6640>
# <tensorflow.python.keras.layers.pooling.AveragePooling1D object at 0x7f1828ac8430>
# <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f18299f6640>
# <tensorflow.python.keras.layers.pooling.AveragePooling3D object at 0x7f1828ac8430>
# <tensorflow.python.keras.layers.pooling.GlobalMaxPooling1D object at 0x7f18299f6640>
# <tensorflow.python.keras.layers.pooling.GlobalMaxPooling2D object at 0x7f1828ac8430>
# <tensorflow.python.keras.layers.pooling.GlobalMaxPooling3D object at 0x7f1828ab1790>
# <tensorflow.python.keras.layers.pooling.GlobalAveragePooling1D object at 0x7f1828ab1220>
# <tensorflow.python.keras.layers.pooling.GlobalAveragePooling2D object at 0x7f1828ab16a0>
# <tensorflow.python.keras.layers.pooling.GlobalAveragePooling3D object at 0x7f1828ab1790>
# >>>>>>>>>> Core Layers <<<<<<<<<<
# KerasTensor(type_spec=TensorSpec(shape=(None, 4), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# <tensorflow.python.keras.layers.core.Dense object at 0x7f1828b31790>
# <tensorflow.python.keras.layers.core.Activation object at 0x7f1828af54f0>
# <tensorflow.python.keras.layers.embeddings.Embedding object at 0x7f1828b31e80>
# <tensorflow.python.keras.layers.core.Masking object at 0x7f1828b31790>
# <tensorflow.python.keras.layers.core.Lambda object at 0x7f1828b31e20>
# >>>>>>>>>> Normalization Layers <<<<<<<<<<
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1828b31e80>
# <tensorflow.python.keras.layers.normalization.LayerNormalization object at 0x7f1828b33070>
# >>>>>>>>>> Regularization Layers <<<<<<<<<<
# <tensorflow.python.keras.layers.core.Dropout object at 0x7f1828b33340>
# <tensorflow.python.keras.layers.core.SpatialDropout1D object at 0x7f1828b33b80>
# <tensorflow.python.keras.layers.core.SpatialDropout2D object at 0x7f1828b31cd0>
# <tensorflow.python.keras.layers.core.SpatialDropout3D object at 0x7f1828b317f0>
# <tensorflow.python.keras.layers.noise.GaussianDropout object at 0x7f1828b31b20>
# <tensorflow.python.keras.layers.noise.GaussianNoise object at 0x7f1828b31cd0>
# <tensorflow.python.keras.layers.core.ActivityRegularization object at 0x7f1828ab1430>
# <tensorflow.python.keras.layers.noise.AlphaDropout object at 0x7f1828b3fee0>
# >>>>>>>>>> Attention Layers <<<<<<<<<<
# <tensorflow.python.keras.layers.multi_head_attention.MultiHeadAttention object at 0x7f1828b31b20>
# <tensorflow.python.keras.layers.dense_attention.Attention object at 0x7f1828ab1370>
# <tensorflow.python.keras.layers.dense_attention.AdditiveAttention object at 0x7f1828b3fee0>
# >>>>>>>>>> Reshaping Layers <<<<<<<<<<
# <tensorflow.python.keras.layers.core.Reshape object at 0x7f1828b31b20>
# <tensorflow.python.keras.layers.core.Flatten object at 0x7f1828aa2070>
# <tensorflow.python.keras.layers.core.RepeatVector object at 0x7f1828b3ffa0>
# <tensorflow.python.keras.layers.core.Permute object at 0x7f1828b3ffd0>
# <tensorflow.python.keras.layers.convolutional.Cropping1D object at 0x7f1828b3ff40>
# <tensorflow.python.keras.layers.convolutional.Cropping2D object at 0x7f1828b3fee0>
# <tensorflow.python.keras.layers.convolutional.Cropping3D object at 0x7f1828b3fee0>
# <tensorflow.python.keras.layers.convolutional.UpSampling1D object at 0x7f1828b3ffa0>
# <tensorflow.python.keras.layers.convolutional.UpSampling2D object at 0x7f1828ab13a0>
# <tensorflow.python.keras.layers.convolutional.UpSampling3D object at 0x7f1828b3ff40>
# <tensorflow.python.keras.layers.convolutional.ZeroPadding1D object at 0x7f1828b31df0>
# <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f1828b3fee0>
# <tensorflow.python.keras.layers.convolutional.ZeroPadding3D object at 0x7f1828b3ffa0>
# >>>>>>>>>> Merging Layers <<<<<<<<<<
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f1828b31df0>
# <tensorflow.python.keras.layers.merge.Average object at 0x7f1828ac8940>
# <tensorflow.python.keras.layers.merge.Maximum object at 0x7f1828ac8d30>
# <tensorflow.python.keras.layers.merge.Minimum object at 0x7f1828ac8d30>
# <tensorflow.python.keras.layers.merge.Add object at 0x7f1828ac8d30>
# <tensorflow.python.keras.layers.merge.Subtract object at 0x7f182d453eb0>
# <tensorflow.python.keras.layers.merge.Multiply object at 0x7f1828ac8d30>
# <tensorflow.python.keras.layers.merge.Dot object at 0x7f182d453be0>
# >>>>>>>>>> Locally Connected Layers <<<<<<<<<<
# <tensorflow.python.keras.layers.local.LocallyConnected1D object at 0x7f182d453eb0>
# <tensorflow.python.keras.layers.local.LocallyConnected2D object at 0x7f182d453f70>
# 2022-04-29 01:35:19.156575: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-29 01:35:19.157097: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-04-29 01:35:19.179511: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2022-04-29 01:35:19.179533: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: dev813-MS-7B23
# 2022-04-29 01:35:19.179538: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: dev813-MS-7B23
# 2022-04-29 01:35:19.179603: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 450.172.1
# 2022-04-29 01:35:19.179623: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 450.156.0
# 2022-04-29 01:35:19.179628: E tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.156.0 does not match DSO version 450.172.1 -- cannot find working devices in this configuration
# 2022-04-29 01:35:19.179826: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-29 01:35:19.180016: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
# # define preprocessing layer
# def preproc_layer(layer_name, **kwargs):
#     from keras import layers
#     if layer_name == 'TextVectorization':
#         layers.TextVectorization(**kwargs)
#     elif layer_name == 'Normalization':
#         layers.Normalization(**kwargs)
#     elif layer_name == 'Dicretization':
#         layers.Dicretization(**kwargs)
#     elif layer_name == 'CategoryEncoding':
#         layers.CategoryEncoding(**kwargs)
#     elif layer_name == 'Hashing':
#         layers.Hashing(**kwargs)
#     elif layer_name == 'StringLookup':
#         layers.StringLookup(**kwargs)
#     elif layer_name == 'IntegerLookup':
#         layers.IntegerLookup(**kwargs)
#     elif layer_name == 'Resizing':
#         layers.Resizing(**kwargs)
#     elif layer_name == 'Rescaling':
#         layers.Rescaling(**kwargs)
#     elif layer_name == 'CenterCrop':
#         layers.CenterCrop(**kwargs)
#     elif layer_name == 'RandomCrop':
#         layers.RandomCrop(**kwargs)
#     elif layer_name == 'RandomFlip':
#         layers.RandomFlip(**kwargs)
#     elif layer_name == 'RandomTranslation':
#         layers.RandomTranslation(**kwargs)
#     elif layer_name == 'RandomRotation':
#         layers.RandomRotation(**kwargs)
#     elif layer_name == 'RandomZoom':
#         layers.RandomZoom(**kwargs)
#     elif layer_name == 'RandomHeight':
#         layers.RandomHeight(**kwargs)
#     elif layer_name == 'RandomWidth':
#         layers.RandomWidth(**kwargs)
#     elif layer_name == 'RandomContrast':
#         layers.RandomContrast(**kwargs)
#     else:
#         return None

# print(preproc_layer('TextVectorization'))
# print(preproc_layer('Normalization'))
# print(preproc_layer('Dicretization'))
# print(preproc_layer('CategoryEncoding'))
# print(preproc_layer('Hashing', num_bins=4))
# print(preproc_layer('StringLookup'))
# print(preproc_layer('IntegerLookup'))
# print(preproc_layer('Resizing', height=4, width=8))
# print(preproc_layer('Rescaling', scale=0.5))
# print(preproc_layer('CenterCrop', height=4, width=8))
# print(preproc_layer('RandomCrop', height=4, width=8))
# print(preproc_layer('RandomFlip'))
# print(preproc_layer('RandomTranslation', height=4, width=8))
# print(preproc_layer('RandomRotation', factor=0.3))
# print(preproc_layer('RandomZoom', height_factor=0.5))
# print(preproc_layer('RandomHeight', factor=0.3))
# print(preproc_layer('RandomWidth', factor=0.3))
# print(preproc_layer('RandomContrast', factor=0.3))
